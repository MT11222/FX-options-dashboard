# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import polars as pl
import datetime as dt
import random

# %%
#types of plots are plt. plot, scatter, bar, hist
x = [1, 2, 3, 4, 5]
y= [2, 4, 8, 16, 32]

plt.plot(x,y)
plt.xlabel("work")
plt.ylabel("outcome")
plt.title("Bleed for it")
plt.show()

categories = ['A', 'B', 'C', 'D']
values = [5, 10, 18, 12]
plt.bar(categories, values)
plt.show()
